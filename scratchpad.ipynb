# %%
import pandas as pd
import numpy as np

# %%
# x = '10 minutes to pandas'.split()
'-'.join('10 minutes to pandas'.split())
# Out:
# '10-minutes-to-pandas'

# %%
'10 minutes to pandas'.replace(' ', '-')
# Out:
# '10-minutes-to-pandas'
